# %% [markdown]
# <a href="https://colab.research.google.com/github/rajsaumyaa/ML_labs/blob/main/Welcome_to_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Linear Regression**

# %% [markdown]
# ## Objective:
# The objective of this analysis is to build a linear regression model to predict housing prices based on various features provided in the dataset.

# %%
import pandas as pd

# %%
house = pd.read_csv('https://github.com/YBIFoundation/Dataset/raw/main/Boston.csv')

# %%
house.head()
# Out:
#       CRIM    ZN  INDUS  CHAS     NX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %%
house.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    float64
#  1   ZN       506 non-null    float64
#  2   INDUS    506 non-null    float64
#  3   CHAS     506 non-null    int64
#  4   NX       506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      506 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    int64
#  9   TAX      506 non-null    float64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    506 non-null    float64
#  13  MEDV     506 non-null    float64
# dtypes: float64(12), int64(2)
# memory usage: 55.5 KB

# %%
house.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS          NX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
house.head(20)
# Out:
#        CRIM    ZN  INDUS  CHAS     NX     RM    AGE     DIS  RAD    TAX  \
# 0   0.00632  18.0   2.31     0  0.538  6.575   65.2  4.0900    1  296.0
# 1   0.02731   0.0   7.07     0  0.469  6.421   78.9  4.9671    2  242.0
# 2   0.02729   0.0   7.07     0  0.469  7.185   61.1  4.9671    2  242.0
# 3   0.03237   0.0   2.18     0  0.458  6.998   45.8  6.0622    3  222.0
# 4   0.06905   0.0   2.18     0  0.458  7.147   54.2  6.0622    3  222.0
# 5   0.02985   0.0   2.18     0  0.458  6.430   58.7  6.0622    3  222.0
# 6   0.08829  12.5   7.87     0  0.524  6.012   66.6  5.5605    5  311.0
# 7   0.14455  12.5   7.87     0  0.524  6.172   96.1  5.9505    5  311.0
# 8   0.21124  12.5   7.87     0  0.524  5.631  100.0  6.0821    5  311.0
# 9   0.17004  12.5   7.87     0  0.524  6.004   85.9  6.5921    5  311.0
# 10  0.22489  12.5   7.87     0  0.524  6.377   94.3  6.3467    5  311.0
# 11  0.11747  12.5   7.87     0  0.524  6.009   82.9  6.2267    5  311.0
# ...

# %%
house.tail(20)
# Out:
#         CRIM   ZN  INDUS  CHAS     NX     RM   AGE     DIS  RAD    TAX  \
# 486  5.69175  0.0  18.10     0  0.583  6.114  79.8  3.5459   24  666.0
# 487  4.83567  0.0  18.10     0  0.583  5.905  53.2  3.1523   24  666.0
# 488  0.15086  0.0  27.74     0  0.609  5.454  92.7  1.8209    4  711.0
# 489  0.18337  0.0  27.74     0  0.609  5.414  98.3  1.7554    4  711.0
# 490  0.20746  0.0  27.74     0  0.609  5.093  98.0  1.8226    4  711.0
# 491  0.10574  0.0  27.74     0  0.609  5.983  98.8  1.8681    4  711.0
# 492  0.11132  0.0  27.74     0  0.609  5.983  83.5  2.1099    4  711.0
# 493  0.17331  0.0   9.69     0  0.585  5.707  54.0  2.3817    6  391.0
# 494  0.27957  0.0   9.69     0  0.585  5.926  42.6  2.3817    6  391.0
# 495  0.17899  0.0   9.69     0  0.585  5.670  28.8  2.7986    6  391.0
# 496  0.28960  0.0   9.69     0  0.585  5.390  72.9  2.7986    6  391.0
# 497  0.26838  0.0   9.69     0  0.585  5.794  70.6  2.8927    6  391.0
# ...

# %%
house.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS          NX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
house.columns
# Out:
# Index(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
#        'PTRATIO', 'B', 'LSTAT', 'MEDV'],
#       dtype='object')

# %%
y = house['MEDV']

# %%
X = house.drop(['MEDV'],axis=1)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,train_size=0.7, random_state=2529)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((354, 13), (152, 13), (354,), (152,))

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
model.intercept_
# Out:
# np.float64(34.21916368862993)

# %%
model.coef_
# Out:
# array([-1.29412069e-01,  3.65184937e-02,  1.54418944e-02,  2.35486887e+00,
#        -2.04171489e+01,  4.41356565e+00,  4.61075512e-03, -1.58626723e+00,
#         2.51478665e-01, -9.59591213e-03, -9.64169204e-01,  1.00972679e-02,
#        -5.43198745e-01])

# %%
y_pred = model.predict(X_test)

# %%
y_pred
# Out:
# array([31.71733828, 22.02143302, 21.16613197, 39.77837246, 20.10258512,
#        22.86056216, 18.35574643, 14.7902735 , 22.55778646, 21.34594953,
#        18.38491085, 27.9664665 , 29.85929012,  6.44680773, 10.68297311,
#        26.24809521, 21.89368671, 25.22692365,  3.62385942, 36.21920372,
#        24.07812335, 22.94103934, 14.27095261, 20.79013279, 24.22725035,
#        16.7379611 , 18.74856986, 20.96709658, 28.513571  , 20.86346628,
#         9.23450577, 17.06754852, 22.06953886, 22.23121875, 39.25875323,
#        26.16769924, 42.50354003, 19.34517962, 34.51869058, 14.07023676,
#        13.81055358, 23.27727535, 11.79100403,  9.01040731, 21.64587594,
#        25.55339317, 18.16941728, 16.81991401, 14.66170215, 14.86477172,
#        33.78924259, 33.26959074, 15.49208778, 24.08269034, 27.63531226,
#        19.58288727, 45.02488529, 20.96959671, 20.07202649, 27.67146866,
#        34.59154418, 12.71353064, 23.66247812, 31.65792337, 28.97459925,
# ...

# %%
from sklearn.metrics import mean_absolute_error, mean_absolute_percentage_error, mean_squared_error

# %%
mean_absolute_error(y_test,y_pred)
# Out:
# 3.155030927602485

# %%
mean_absolute_percentage_error(y_test,y_pred)
# Out:
# 0.1635593588221789

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 20.718012877838433

# %%
from sklearn.metrics import r2_score, mean_squared_error
import numpy as np

# Example: suppose y_test = actual values, y_pred = predicted values

# R2 Score
r2 = r2_score(y_test, y_pred)

# RMSE (Root Mean Squared Error)
rmse = np.sqrt(mean_squared_error(y_test, y_pred))

print("R2 Score:", r2)
print("RMSE:", rmse)
# Out:
# R2 Score: 0.6551914852365536
# RMSE: 4.5517043926246386

# %%
import matplotlib.pyplot as plt

# Example data (replace with your y_test and y_pred)
y_test = [3, 5, 7, 9]
y_pred = [2.5, 5.2, 6.8, 9.1]

# Scatter plot: Actual vs Predicted
plt.figure(figsize=(6,6))
plt.scatter(y_test, y_pred, alpha=0.6, color='blue')
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], 'r--', linewidth=2)
plt.xlabel("Actual Values")
plt.ylabel("Predicted Values")
plt.title("Actual vs Predicted")
plt.show()

# %%
import matplotlib.pyplot as plt
# Use only the RM column from X_test
plt.scatter(X_test['RM'], y_test, color='blue', label='Actual')
plt.plot(X_test['RM'], y_pred, color='red', linewidth=2, label='Predicted')

plt.xlabel('Average Number of Rooms (RM)')
plt.ylabel('Median Value of Homes (MEDV)')
plt.title('Linear Regression: RM vs MEDV')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-2715906744.py in <cell line: 0>()
#       1 import matplotlib.pyplot as plt
#       2 # Use only the RM column from X_test
# ----> 3 plt.scatter(X_test['RM'], y_test, color='blue', label='Actual')
#       4 plt.plot(X_test['RM'], y_pred, color='red', linewidth=2, label='Predicted')
#       5
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/_api/deprecation.py in wrapper(*args, **kwargs)
#     451                 "parameter will become keyword-only in %(removal)s.",
#     452                 name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453         return func(*args, **kwargs)
#     454
#     455     # Don't modify *func*'s signature, as boilerplate.py needs it.
#
# ...
